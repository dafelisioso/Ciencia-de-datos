                         2341, 2443, 2631, 2414, 2581, 2699, 2795, 2779, 2583, 2771, 
                         2846, 2839, 2767, 2696, 2954, 3098, 3082, 3074, 3000, 3345, 
                         3134, 3207, 3189, 2717, 2951, 2902, 3049, 2589, 2529, 2692, 
                         2564, 2404, 2423, 2203, 2371, 2039, 2035, 2207, 1971, 2031, 
                         2306, 2038, 2265, 1925, 2169, 2112, 2172, 2131, 2289, 2346, 
                         2463, 2394, 2230, 2443, 2774, 2609, 2697, 3059, 2622, 2925, 
                         2946, 3143, 2938, 2870, 2843, 2751, 3309, 3168, 2985, 3234, 
                         3379, 3379, 3392, 3394, 3385, 3191, 3287, 3127, 3110, 2857, 
                         2874, 3084, 2777, 2476]

# %%
Lavanderia = [17*j for j in pantalones_producidos]

# %% [markdown]
# # Empleados

# %% [markdown]
# ## Talle1

# %% [markdown]
# ### Nombres

# %%
p1 = 'Irma Ramirez González' 
p2 = 'Omar Gutierrez Aguilar' 
p3 = 'Valbina Soriano Rios'
p4 = 'Laura García Ramirez'
p5 = 'Diego Armando Ramirez Mayoral'
p6 = 'Juan Arellano Guzman'
p7 = 'Benjamin Campos Villeda'
p8 = 'Adela Vargas Duarte'
p9 = 'Maricela Rivero Arreola'
p10 = 'Maricruz Yepez Lopez'
p11 = 'Nadia López Lazcano'
p12 = 'Anyelina Clavellina Rosas'
p13 = 'Rosa Guzman Padilla'
p14 = 'Rosario Zariñán Barrientos'
p15 = 'Alicia Reyes Fernandez'
p16 = 'Cesar Garces Rojas'

# %% [markdown]
# ### Sueldos

# %%
sp1 = [1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320,
       1320, 1320, 1320, 1320, 1320,    0, 1320, 1320,    0, 1320, 1320,
          0, 1320, 1320, 1320,    0, 1320, 1320,    0,    0,    0, 1430,
       1430, 1430, 1430, 1430, 1430, 1430, 1430,    0, 1430, 1430,    0,
       1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430,    0, 1430, 1430,
       1430,    0, 1540, 1540,    0, 1540, 1540, 1540, 1540,    0, 1540,
       1540, 1540, 1540, 1540,    0, 1540, 1540, 1540, 1540, 1540, 1540,
       1540, 1540, 1540, 1540,    0,    0, 1650, 1650, 1650,    0, 1650,
       1650, 1650, 1650, 1650, 1650,    0,    0, 1650, 1650, 1650, 1650,
       1650, 1650,    0, 1650, 1650, 1650, 1650, 1650, 1650, 1650,    0,
       1650, 1650, 1650, 1650,    0, 1650, 1650, 1650, 1650, 1650, 1650,
       1650, 1650, 1650, 1650,    0, 1650, 1650, 1650, 1650, 1650, 1650,
          0, 1650, 1650,    0,    0, 1760, 1760, 1760, 1760,    0, 1760,
       1760] #...

sp2 = [1100, 1100,    0, 1100, 1100, 1100, 1100, 1100, 1100,    0,    0,
       1100, 1100, 1100, 1100,    0, 1100, 1100, 1100, 1100, 1100, 1100,
       1100, 1100, 1100, 1100, 1100, 1100, 1100,    0,    0, 1210, 1210,
          0, 1210,    0,    0,    0, 1210, 1210,    0, 1210, 1210, 1210,
       1210, 1210,    0, 1210,    0,    0,    0,    0,    0,    0,    0,
       1210,    0, 1320, 1320, 1320,    0, 1320, 1320, 1320, 1320, 1320,
       1320,    0,    0, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1
       323, 317, 308, 323, 275, 262, 239, 268, 278, 251, 258, 257, 239,
       236, 233, 218, 237, 186, 235, 230, 227, 233, 204, 231, 241, 235,
       242, 214, 222, 238, 251, 248, 228, 247, 257, 268, 289, 265, 283,
       296, 306, 305, 283, 304, 295, 294, 327, 319, 349, 366, 343, 342] #Semana 1-78

pp33 = [245, 236, 252, 208, 245, 279, 258, 267, 274, 336, 332, 333, 331,
       328, 334, 350, 338, 346, 309, 331, 335, 333, 367, 348, 350, 360,
       402, 394, 382, 401, 338, 322, 294, 330, 341, 309, 317, 316, 294,
       290, 286, 268, 292, 229, 289, 283, 279, 287, 251, 284, 296, 289,
       297, 264, 273, 292, 305, 301, 277, 300, 312, 325, 350, 322, 343,
       359, 371, 369, 344, 368, 358, 357] #Semana 1-72

piezasprod2=[np.sum(pp17)+np.sum(pp18)+np.sum(pp19)+np.sum(pp20)+np.sum(pp21)+np.sum(pp22)+np.sum(pp23)+np.sum(pp24)+np.sum(pp25)+np.sum(pp26)+np.sum(pp27)+np.sum(pp28)+np.sum(pp29)+np.sum(pp30)+np.sum(pp31)+np.sum(pp32)+ np.sum(pp33)]
piezasprod2
# Out:
# [376423]

# %% [markdown]
# ## Perfilado de los datos

# %% [markdown]
# ### Completez

# %%
porcentajes_de_completes = []
porcentajes_de_completes.append(np.count_nonzero(np.array(pantalones_vendidos))/len(pantalones_vendidos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(ventas))/len(ventas)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Hilos))/len(Hilos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Refaxiones))/len(Refaxiones)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Tela))/len(Tela)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Cierres))/len(Cierres)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Botones))/len(Botones)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Modelos))/len(Modelos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Etiquetas))/len(Etiquetas)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Deshebrado))/len(Deshebrado)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(pantalones_producidos))/len(pantalones_producidos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Lavanderia))/len(Lavanderia)* 100)

# %%
atributos = ["Pantalones Vendidos","Ventas","Hilos","Refaxiones","Tela","Cierres","Botones","Modelos","Etiquetas","Deshebrado","Pantalones Producidos","Lavanderia","Sueldos Taller 1","Piezas Taller 1","Sueldos Taller 2","Piezas Taller 2"]

# %%
l1 = [sp1, sp2, sp3, sp4, sp5, sp6, sp7, sp8, sp9,
sp10, sp11, sp12, sp13, sp14, sp15, sp16, sp17,
sp18, sp19, sp20, sp21, sp22, sp23, sp24, sp25,
sp26, sp27, sp28, sp29, sp30, sp31, sp32, sp33]

# %%
s1 = 0
s2 = 0
for j in l1[:16]:
    s1 += np.count_nonzero(j)
    s2 += len(j)

porcentajes_de_completes.append(s1/s2*100)
for j,v in enumerate(porcentajes_de_completes):
    porcentajes_de_completes[j] = np.round_(v,2)

porcentajes_de_completes.append(100.0)

# %%
s1 = 0
s2 = 0
for j in l1[16:]:
    s1 += np.count_nonzero(j)
    s2 += len(j)

porcentajes_de_completes.append(s1/s2*100)
for j,v in enumerate(porcentajes_de_completes):
    porcentajes_de_completes[j] = np.round_(v,2)

porcentajes_de_completes.append(100.0)

# %%
df = pd.DataFrame([porcentajes_de_completes,atributos]).transpose()
df.columns = ["Porcentaje de Completes" , "Columnas"]

# %%
df.plot(kind="barh",x="Columnas",y="Porcentaje de Completes",figsize=(10,10),title="Porcentajes de Completez por Atributo",legend=False,xlabel='Atributos',ylabel="Porcentajes de Completez por Atributo",fontsize=15,color='purple')
plt.ylabel("Columnas",fontsize=15)
plt.xlabel("Porcentaje de Completez",fontsize=15)
plt.title("Porcentajes de Completez por Atributo",fontsize=15)
plt.show()

# %% [markdown]
# ### Busqueda de Outliers

# %%
plt.figure(figsize=(10,10))
plt.boxplot(np.array(pantalones_vendidos))
plt.title("Boxplot de los pantalones vendidos",fontsize=15)
plt.ylabel("Cantidad de pantalones vendidos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.boxplot(np.array(pantalones_producidos))
plt.title("Boxplot de los pantalones producidos",fontsize=15)
plt.ylabel("Cantidad de pantalones producidos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(ventas):
    if ventas[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de el dinero de las ventas",fontsize=15)
plt.ylabel("Cantidade en pesos de las ventas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Hilos):
    if Hilos[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de lo gastado en Hilos",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Hilos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Cierres):
    if Cierres[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de lo gastado en Cierres",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Cierres",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Botones):
    if Botones[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de lo gastado en Botones",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Botones",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Etiquetas):
    if Etiquetas[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de lo gastado en Etiquetas",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Etiquetas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
for j,v in enumerate(Deshebrado):
    if Deshebrado[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.boxplot(np.array(y))
plt.title("Boxplot de lo gastado en Desebrado",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Desebrado",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
t = []
for j in l1:
    t += j
plt.figure(figsize=(10,10))
plt.boxplot(np.array(t))
plt.title("Boxplot de los sueldos",fontsize=15)
plt.ylabel("Cantidad en pesos gastada en Sueldos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # Limpieza

# %% [markdown]
# ## Ventas

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(ventas):
    if ventas[j] != 0.0:
        y.append(v)
        x.append(pantalones_vendidos[j])
    else:
        x_prime.append(pantalones_vendidos[j])

plt.figure(figsize=(10,7))
plt.scatter(x,y)
plt.title("Ventas vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Vendidos",fontsize=15)
plt.ylabel("Ventas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
ventas_lineal = LinearRegression()
ventas_lineal.fit(np.array(x).reshape(len(x),1),np.array(y).reshape(len(y),1))
# Out:
# LinearRegression()

# %%
for j,v in enumerate(ventas):
    if ventas[j] == 0.0:
        ventas[j] = int(np.round_(ventas_lineal.predict(np.array(pantalones_vendidos[j]).reshape(1,1))[0][0]))

y_prime = np.round_(ventas_lineal.predict(np.array(x_prime).reshape(len(x_prime),1)))

# %%
xx = np.linspace(1750 ,3250 ,2)
yy = ventas_lineal.predict(xx.reshape(len(xx),1))

plt.figure(figsize=(10,10))
plt.plot(xx,yy,c="r",label="Ajuste Lineal")
plt.scatter(np.array(pantalones_vendidos),np.array(ventas),c="b",label="Datos Completos",alpha=0.7)
plt.scatter(x_prime,y_prime,c="g",label="Predicciones")
plt.title("Ventas vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Vendidos",fontsize=15)
plt.ylabel("Ventas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(0., 0., 0.35, 1),fontsize=15)
plt.show()

# %% [markdown]
# ## Hilos

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Hilos):
    if Hilos[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Hilos vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Hilos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
hilos_lineal = LinearRegression()
hilos_lineal.fit(np.array(x).reshape(len(x),1),np.array(y).reshape(len(y),1))
for j,v in enumerate(Hilos):
    if Hilos[j] == 0.0:
        Hilos[j] = int(np.round_(hilos_lineal.predict(np.array(pantalones_producidos[j]).reshape(1,1))[0][0]))

y_prime = np.round_(hilos_lineal.predict(np.array(x_prime).reshape(len(x_prime),1)))

# %%
xx = np.linspace(1750 ,3250 ,2)
yy = hilos_lineal.predict(xx.reshape(len(xx),1))

plt.figure(figsize=(10,10))
plt.plot(xx,yy,c="r",label="Ajuste Lineal")
plt.scatter(np.array(pantalones_producidos),np.array(Hilos),c="orange",label="Datos Completos")
plt.scatter(x_prime,y_prime,c="g",label="Predicciones")
plt.title("Cantidad Gastada en Hilos vs Pantalones Producidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Hilos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(0., 0., 0.35, 1),fontsize=15)
plt.show()

# %% [markdown]
# ## Cierres

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Cierres):
    if Cierres[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Cierres vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Cierres",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
cierres_lineal = LinearRegression()
cierres_lineal.fit(np.array(x).reshape(len(x),1),np.array(y).reshape(len(y),1))
for j,v in enumerate(Cierres):
    if Cierres[j] == 0.0:
        Cierres[j] = int(np.round_(cierres_lineal.predict(np.array(pantalones_producidos[j]).reshape(1,1))[0][0]))

y_prime = np.round_(cierres_lineal.predict(np.array(x_prime).reshape(len(x_prime),1)))

# %%
xx = np.linspace(1750 ,3250 ,2)
yy = cierres_lineal.predict(xx.reshape(len(xx),1))

plt.figure(figsize=(10,10))
plt.plot(xx,yy,c="r",label="Ajuste Lineal")
plt.scatter(np.array(pantalones_producidos),np.array(Cierres),c="orange",label="Datos Completos")
plt.scatter(x_prime,y_prime,c="g",label="Predicciones")
plt.title("Cantidad Gastada en Cierres vs Pantalones Producidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Cierres",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(0., 0., 0.35, 1),fontsize=15)
plt.show()

# %% [markdown]
# ## Botones

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Botones):
    if Botones[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Botones vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Botones",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
botones_lineal = LinearRegression()
botones_lineal.fit(np.array(x).reshape(len(x),1),np.array(y).reshape(len(y),1))
for j,v in enumerate(Botones):
    if Botones[j] == 0.0:
        Botones[j] = int(np.round_(botones_lineal.predict(np.array(pantalones_producidos[j]).reshape(1,1))[0][0]))

y_prime = np.round_(botones_lineal.predict(np.array(x_prime).reshape(len(x_prime),1)))

# %%
xx = np.linspace(1750 ,3250 ,2)
yy = botones_lineal.predict(xx.reshape(len(xx),1))

plt.figure(figsize=(10,10))
plt.plot(xx,yy,c="r",label="Ajuste Lineal")
plt.scatter(np.array(pantalones_producidos),np.array(Botones),c="orange",label="Datos Completos")
plt.scatter(x_prime,y_prime,c="g",label="Predicciones")
plt.title("Cantidad Gastada en Botones vs Pantalones Producidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Botones",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(0., 0., 0.35, 1),fontsize=15)
plt.show()

# %% [markdown]
# ## Etiquetas

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(Etiquetas):
    if Etiquetas[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Etiquetas vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Etiquetas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
etiquetas_lineal = LinearRegression()
etiquetas_lineal.fit(np.array(x).reshape(len(x),1),np.array(y).reshape(len(y),1))
for j,v in enumerate(Etiquetas):
    if Etiquetas[j] == 0.0:
        Etiquetas[j] = int(np.round_(etiquetas_lineal.predict(np.array(pantalones_producidos[j]).reshape(1,1))[0][0]))

y_prime = np.round_(etiquetas_lineal.predict(np.array(x_prime).reshape(len(x_prime),1)))

# %%
xx = np.linspace(1750 ,3250 ,2)
yy = etiquetas_lineal.predict(xx.reshape(len(xx),1))

plt.figure(figsize=(10,10))
plt.plot(xx,yy,c="r",label="Ajuste Lineal")
plt.scatter(np.array(pantalones_producidos),np.array(Etiquetas),c="orange",label="Datos Completos")
plt.scatter(x_prime,y_prime,c="g",label="Predicciones")
plt.title("Cantidad Gastada en Etiquetas vs Pantalones Producidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Etiquetas",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(0., 0., 0.35, 1),fontsize=15)
plt.show()

# %% [markdown]
# ## Desebrado

# %%
x = []
y = []
for j,v in enumerate(Deshebrado):
    if Deshebrado[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Deshebrado vs Pantalones Producidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Deshebrado",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
x = []
y = []
for j,v in enumerate(Deshebrado):
    if Deshebrado[j] != 0.0:
        y.append(v)
        x.append(pantalones_vendidos[j])

plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title("Cantidad Gastada en Desebrado vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones Producidos",fontsize=15)
plt.ylabel("Cantidad Gastada en Desebrado",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
y = []
for j,v in enumerate(Deshebrado):
    if Deshebrado[j] != 0.0:
        y.append(v)

plt.figure(figsize=(10,7))
plt.hist(y,bins=15,color='purple')
plt.title("Histograma de lo Gastado en Deshebrado",fontsize=15)
plt.xlabel("Cantidad Gastada en Deshebrado",fontsize=15)
plt.ylabel("Frecuencia",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
print('La cantidad promedio de gasto en deshebrado por semana es;',np.mean(y))
# Out:
# La cantidad promedio de gasto en deshebrado por semana es; 814.1803278688525

# %%
for j,v in enumerate(Deshebrado):
    if v == 0:
        Deshebrado[j] = int(np.median(np.array(Deshebrado)))

# %% [markdown]
# ## Sueldos

# %%
import datetime as DT

# %%
lista1 = [0,0,0,31,0,0,49,36,27,96,37,31,19,10,0,0,0,0,0,0,29,12,75,69,55,87,140,0,30,0,0,0,0]
minimos = []
for j in l1:
    for k in j:
        if k == 0:
            continue
        else:
            minimos.append(k)
            break

# %%
fs = []
for j in fechas_semanles:
    fs.append(DT.datetime.strptime(j,"%Y-%m-%d"))

# %%
fm = []
for j,v in enumerate(fechas_mensuales):
    if j%6 == 1:
        fm.append(DT.datetime.strptime(v,"%Y-%m-%d"))

# %%
for j in l1[:3]:
    print(j)
# Out:
# [1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 1320, 0, 1320, 1320, 0, 1320, 1320, 0, 1320, 1320, 1320, 0, 1320, 1320, 0, 0, 0, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 0, 1430, 1430, 0, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 1430, 0, 1430, 1430, 1430, 0, 1540, 1540, 0, 1540, 1540, 1540, 1540, 0, 1540, 1540, 1540, 1540, 1540, 0, 1540, 1540, 1540, 1540, 1540, 1540, 1540, 1540, 1540, 1540, 0, 0, 1650, 1650, 1650, 0, 1650, 1650, 1650, 1650, 1650, 1650, 0, 0, 1650, 1650, 1650, 1650, 1650, 1650, 0, 1650, 1650, 1650, 1650, 1650, 1650, 1650, 0, 1650, 1650, 1650, 1650, 0, 1650, 1650, 1650, 1650, 1650, 1650, 1650, 1650, 1650, 1650, 0, 1650, 1650, 1650, 1650, 1650, 1650, 0, 1650, 1650, 0, 0, 1760, 1760, 1760, 1760, 0, 1760, 1760]
# ...

# %%
fm
# Out:
# [datetime.datetime(2019, 7, 1, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(2020, 7, 1, 0, 0),
#  datetime.datetime(2021, 1, 1, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2022, 1, 1, 0, 0)]

# %%
for j1,v1 in enumerate(l1):
    for j2,v2 in enumerate(v1):
        if v2==0:
            s = False
            for j3,v3 in enumerate(fm):
                if fs[lista1[j1]+j2] > v3:
                    s = True
                    v1[j2] = minimos[j1]+110*(j3)
                    break
            if s == False:
                v1[j2] = minimos[j1]

# %% [markdown]
# ## Verificación de la completez

# %%
porcentajes_de_completes = []
porcentajes_de_completes.append(np.count_nonzero(np.array(pantalones_vendidos))/len(pantalones_vendidos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(ventas))/len(ventas)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Hilos))/len(Hilos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Refaxiones))/len(Refaxiones)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Tela))/len(Tela)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Cierres))/len(Cierres)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Botones))/len(Botones)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Modelos))/len(Modelos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Etiquetas))/len(Etiquetas)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Deshebrado))/len(Deshebrado)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(pantalones_producidos))/len(pantalones_producidos)* 100)
porcentajes_de_completes.append(np.count_nonzero(np.array(Lavanderia))/len(Lavanderia)* 100)

# %%
s1 = 0
s2 = 0
for j in l1[:16]:
    s1 += np.count_nonzero(j)
    s2 += len(j)

porcentajes_de_completes.append(s1/s2*100)
for j,v in enumerate(porcentajes_de_completes):
    porcentajes_de_completes[j] = np.round_(v,2)

porcentajes_de_completes.append(100.0)

# %%
s1 = 0
s2 = 0
for j in l1[16:]:
    s1 += np.count_nonzero(j)
    s2 += len(j)

porcentajes_de_completes.append(s1/s2*100)
for j,v in enumerate(porcentajes_de_completes):
    porcentajes_de_completes[j] = np.round_(v,2)

porcentajes_de_completes.append(100.0)

# %%
df1 = pd.DataFrame([porcentajes_de_completes,atributos]).transpose()
df1.columns = ["Porcentaje de Completes" , "Columnas"]

# %%
df1.plot(kind="barh",x="Columnas",y="Porcentaje de Completes",figsize=(10,10),title="Porcentajes de Completes por Atributo",legend=False,xlabel='Atributos',ylabel="Porcentajes de Completes por Atributo",fontsize=15,color='red')
plt.ylabel("Columnas",fontsize=15)
plt.xlabel("Porcentaje de Completez",fontsize=15)
plt.title("Porcentajes de Completez por Atributo",fontsize=15)
plt.show()

# %% [markdown]
# #Consultas

# %% [markdown]
# ## Consulta 1
# Queremos ver las ventas totales por semana, presentada como una serie de tiempo.

# %%
import matplotlib.dates as mdates
dates = np.array(mdates.num2date(mdates.drange(DT.datetime(2019, 6, 6),DT.datetime(2022, 3, 10),DT.timedelta(days=7))))
dates = dates.reshape((144,1))

# %%
plt.figure(figsize=(10,7))
plt.plot(dates[:,0],ventas)
plt.title("Ventas por semana",fontsize=15)
plt.xlabel("Fechas",fontsize=15)
plt.ylabel("Ventas en Pesos Mexicanos",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Consulta 2
# Queremos ver la cantidad de pantalones que se vendieron por semana.

# %%
plt.figure(figsize=(10,7))
plt.plot(dates[:,0],pantalones_vendidos)
plt.title("Pantalones vendidos por semana",fontsize=15)
plt.xlabel("Fechas",fontsize=15)
plt.ylabel("Cantidad de pantalones vendidos",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Consulta 3
# Queremos ver la distribución de el promedio de pantalones que producen los distintos trabajadores

# %%
pantalonestot=[np.mean(pp1),np.mean(pp2),np.mean(pp3),np.mean(pp4),np.mean(pp5),
               np.mean(pp6),np.mean(pp7),np.mean(pp8),np.mean(pp9),np.mean(pp10),np.mean(pp11),np.mean(pp12),np.mean(pp13),np.mean(pp14),np.mean(pp15),np.mean(pp16)]
plt.hist(pantalonestot,bins=6,color='darkred')
plt.title('Histograma del promedio de piezas producidas por trabajador al mes')
plt.xlabel('Número de piezas')
plt.ylabel('Cantidad de trabajadores')
plt.show()

# %% [markdown]
# ## Consulta 4
# Ver como cuanto se suele gastar en Deshebrado por semana

# %%
y = []
for j,v in enumerate(Deshebrado):
    if Deshebrado[j] != 0.0:
        y.append(v)

plt.figure(figsize=(10,7))
plt.hist(y,bins=15,color='purple')
plt.title("Histograma de lo Gastado en Deshebrado",fontsize=15)
plt.xlabel("Cantidad Gastada en Deshebrado",fontsize=15)
plt.ylabel("Frecuencia",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
print('La cantidad promedio de gasto en deshebrado por semana es;',np.mean(y))
# Out:
# La cantidad promedio de gasto en deshebrado por semana es; 812.0138888888889

# %% [markdown]
# ## Consulta 5
# Queremos ver cual ha sido el total gastado en sueldos de todo el tiempo que lleva el negocio:

# %%
total_salarios = 0
for j in l1:
    total_salarios += np.sum(np.array(j))

total_salarios
# Out:
# 3850000

# %%
total_salarios = 0
for j in l1:
    total_salarios += np.sum(np.array(j))

print('En total se ha gastado en salarios para los trabjadores',total_salarios, 'pesos')
# Out:
# En total se ha gastado en salarios para los trabjadores 3850000 pesos

# %% [markdown]
# ## Consluta 6
# Queremos ver las ganancias totales, es decir cuanto se ha ganado menos lo que se ha gastado

# %%
ganacias = np.sum(ventas)
gastos = np.sum(Hilos) + np.sum(Refaxiones) + np.sum(Tela) + np.sum(Cierres) + np.sum(Lavanderia) + np.sum(Botones) + np.sum(Etiquetas) + np.sum(Modelos) + np.sum(Deshebrado) + total_salarios
print('Lo ganado sin contar gastos es:',ganacias)
# Out:
# Lo ganado sin contar gastos es: 38630362

# %%
print('El total gastado es de:',gastos)
# Out:
# El total gastado es de: 34615032

# %%
print('El total ganado es de:',(ganacias-gastos))
# Out:
# El total ganado es de: 4015330

# %% [markdown]
# ## Consulta 7
# Queremos ver cual es la ganancia aproximada por cada pantalón vendido

# %%
print('El porcentaje de ganancia aproximado por cada pantalón vendido es de :',ganacias/gastos-1)
# Out:
# El porcentaje de ganancia aproximado por cada pantalón vendido es de : 0.11599960387152031

# %%
ventas_total = np.sum(np.array(ventas)) 
gastos = np.sum(Hilos) + np.sum(Refaxiones) + np.sum(Tela) + np.sum(Cierres) + np.sum(Lavanderia) + np.sum(Botones) + np.sum(Etiquetas) + np.sum(Modelos) + np.sum(Deshebrado) + total_salarios
print("Ganancia promedio por semana",(ventas_total-gastos)/144)
print("Ratio de ganancia", ventas_total/gastos)
print("Costo promedio del pantalón", np.sum(ventas)/np.sum(pantalones_vendidos))
# Out:
# Ganancia promedio por semana 27884.23611111111
# Ratio de ganancia 1.1159996038715203
# Costo promedio del pantalón 109.24381815302475

# %%
ventas_predichas = np.sum(np.array(pantalones_vendidos)*114)
print("Ventas si el precio promedio del pantalones sube 5 pesos",ventas_predichas)
print("Ratio de ganancia con las ventas predichas",ventas_predichas/gastos)
# Out:
# Ventas si el precio promedio del pantalones sube 5 pesos 40312224
# Ratio de ganancia con las ventas predichas 1.1645872232618477

# %% [markdown]
# ## Consulta 8
# Queremos comparar cuantas piezas se hicieron en el taller y taller dos para ver cual taller es más
# eficiente

# %%
piezasprod1=[np.sum(pp1)+np.sum(pp2)+np.sum(pp3)+np.sum(pp4)+np.sum(pp5)+np.sum(pp6)
+np.sum(pp7)+np.sum(pp8)+np.sum(pp9)+np.sum(pp10)+np.sum(pp11)+np.sum(pp12)+np.sum(pp13)+np.sum(pp14)+np.sum(pp15)+np.sum(pp16)]

piezasprod2=[np.sum(pp17)+np.sum(pp18)+np.sum(pp19)+np.sum(pp20)+np.sum(pp21)+
             np.sum(pp22)+np.sum(pp23)+np.sum(pp24)+np.sum(pp25)+np.sum(pp26)+np.sum(pp27)+np.sum(pp28)+np.sum(pp29)+np.sum(pp30)+np.sum(pp31)+np.sum(pp32)+ np.sum(pp33)]
print('En el taller uno se produjeron:',piezasprod1,'en total y en el taller 2',piezasprod2)
# Out:
# En el taller uno se produjeron: [376038] en total y en el taller 2 [376423]

# %% [markdown]
# ## Consulta 9
# Queremos ver la relación entre cuantos pantalones se producen y los que se venden

# %%
x = []
y = []
x_prime = []
for j,v in enumerate(pantalones_vendidos):
    if ventas[j] != 0.0:
        y.append(v)
        x.append(pantalones_producidos[j])
    else:
        x_prime.append(pantalones_producidos[j])

plt.figure(figsize=(10,7))
plt.scatter(x,y)
plt.title("Pantalones producidos vs Pantalones Vendidos",fontsize=15)
plt.xlabel("Pantalones producidos",fontsize=15)
plt.ylabel("Pantalones vendidos",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Consulta 10
# Queremos ver el trabajador que más produce en el taller uno

# %%
pantalonestot=[np.mean(pp1),np.mean(pp2),np.mean(pp3),np.mean(pp4),np.mean(pp5),
               np.mean(pp6),np.mean(pp7),np.mean(pp8),np.mean(pp9),np.mean(pp10),np.mean(pp11),np.mean(pp12),np.mean(pp13),np.mean(pp14),np.mean(pp15),np.mean(pp16)]
np.max(pantalonestot)

print('El trabajador que más ha hecho en promedio es el pp',pantalonestot.index(np.max(pantalonestot))+1, 'el cual es',p3)
# Out:
# El trabajador que más ha hecho en promedio es el pp 3 el cual es Valbina Soriano Rios
